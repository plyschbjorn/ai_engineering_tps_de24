# %% [markdown]
# # Structure gemini outputs in a robust way

# %%
from google import genai


client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients
    """
)
print(response.text)
# Out:
# Here are a few delicious Asian soup recipes with yummy descriptions and ingredient lists to get your taste buds tingling!
#
# ---
#
# ### 1. Tonkotsu Ramen (Japan)
#
# **Yummy Description:**
# Dive into a bowl of pure comfort with this **rich, creamy, and deeply savory Tonkotsu Ramen**. Imagine a milky white pork bone broth, simmered for hours until it's velvety smooth and bursting with umami. Nestled within are springy, toothsome ramen noodles, crowned with melt-in-your-mouth slices of tender Chashu pork belly, a perfectly jammy marinated soft-boiled egg (Ajitama), crisp scallions, and delicate sheets of nori. Each spoonful is a harmonious symphony of textures and robust flavors – it's a hug in a bowl!
#
# **Ingredients:**
#
# *   **For the Broth (the heart of Tonkotsu):**
#     *   Pork bones (trotters, neck bones, femurs)
#     *   Water
#     *   Aromatics: Ginger, garlic, green onions (white parts)
# *   **For the Chashu (Braised Pork Belly):**
#     *   Pork belly (skin on or off)
#     *   Soy sauce, Mirin, Sake
#     *   Sugar, Water
#     *   Ginger, Garlic, Green onions
# *   **For the Ajitama (Marinated Soft-Boiled Egg):**
#     *   Eggs
#     *   Soy sauce, Mirin, Water
# *   **For the Assembly:**
#     *   Fresh or dried Ramen noodles
#     *   **Toppings:** Sliced Chashu, Ajitama, Nori (seaweed sheets), chopped green onions (green parts), Kikurage (wood ear mushrooms, rehydrated and sliced), Benishoga (pickled ginger - optional).
#     *   **Seasoning (Tare - a concentrated flavoring sauce):** Usually a blend of soy sauce, salt, or miso paste.
#
# ---
#
# ### 2. Tom Yum Goong (Thailand)
#
# **Yummy Description:**
# Brace yourself for a vibrant explosion of flavors with **Tom Yum Goong, Thailand's iconic hot and sour shrimp soup!** This fragrant broth dances on your palate with its perfect balance of spicy, sour, sweet, and salty. Infused with aromatic lemongrass, galangal, kaffir lime leaves, and fiery Thai chilies, it's a sensory delight. Succulent shrimp bob alongside earthy mushrooms and juicy cherry tomatoes, all garnished with fresh cilantro. Each spoonful is an invigorating and utterly addictive journey to the heart of Thai cuisine.
#
# **Ingredients:**
#
# *   **For the Broth:**
#     *   Chicken or shrimp stock (or water)
#     *   Lemongrass (bruised and sliced)
#     *   Galangal (sliced)
#     *   Kaffir lime leaves (torn)
#     *   Thai bird's eye chilies (crushed or sliced, to taste)
#     *   Fish sauce
#     *   Lime juice (freshly squeezed)
#     *   Palm sugar (or regular sugar)
#     *   Tom Yum paste (optional, for extra depth)
# *   **Main Ingredients:**
#     *   Fresh large shrimp (peeled and deveined)
#     *   Mushrooms (straw mushrooms or oyster mushrooms, halved)
#     *   Cherry tomatoes (halved)
# *   **Garnish:**
#     *   Fresh cilantro (chopped)
#
# ---
#
# ### 3. Pho Bo (Vietnamese Beef Noodle Soup)
#
# **Yummy Description:**
# Immerse yourself in the comforting embrace of **Pho Bo, a deeply aromatic and incredibly satisfying Vietnamese beef noodle soup.** Its crystal-clear, slow-simmered broth is a masterpiece, subtly spiced with star anise, cloves, cinnamon, and ginger, creating an intoxicating fragrance. Silky, slippery rice noodles swim alongside tender, thinly sliced beef (often eye of round, brisket, or meatballs). Served with a vibrant platter of fresh herbs like basil and mint, crisp bean sprouts, lime wedges, and fiery jalapeños, it's a build-your-own bowl of pure, soulful deliciousness.
#
# **Ingredients:**
#
# *   **For the Broth:**
#     *   Beef bones (marrow bones, knuckle bones)
#     *   Beef brisket (optional, for flavor and extra meat)
#     *   Onions (charred)
#     *   Ginger (charred)
#     *   Whole spices: Star anise, cinnamon stick, black cardamom pods, cloves, coriander seeds, fennel seeds
#     *   Fish sauce
#     *   Rock sugar (or granulated sugar)
#     *   Salt
#     *   Water
# *   **For the Assembly:**
#     *   Fresh flat rice noodles (Bánh Phở)
#     *   Thinly sliced raw beef (e.g., eye of round, sirloin – to be cooked by the hot broth)
#     *   Cooked beef (brisket, flank, beef meatballs – optional)
# *   **Garnish/Condiments (served on the side):**
#     *   Fresh bean sprouts
#     *   Fresh basil leaves
#     *   Fresh mint leaves
#     *   Lime wedges
#     *   Sliced jalapeños or bird's eye chilies
#     *   Hoisin sauce
#     *   Sriracha chili sauce
#
# ---
#
# ### 4. Laksa (Malaysian/Singaporean Spicy Coconut Noodle Soup)
#
# **Yummy Description:**
# Indulge in the exotic richness of **Laksa, a creamy, spicy, and utterly addictive coconut-based noodle soup!** This vibrant dish boasts a luxurious, thick curry broth infused with a complex blend of aromatics like lemongrass, galangal, chilies, and turmeric, all mellowed by luscious coconut milk. A delightful mix of springy rice vermicelli and chewy egg noodles are generously loaded with succulent shrimp, tender chicken, bouncy fish cakes, and absorbent tofu puffs. Garnished with fresh laksa leaves and a squeeze of lime, it's an intensely flavorful and deeply satisfying culinary adventure.
#
# **Ingredients:**
#
# *   **Laksa Paste (Can be store-bought or homemade):**
#     *   Dried red chilies (rehydrated)
#     *   Shallots, garlic, ginger, galangal
#     *   Lemongrass (white part)
#     *   Turmeric (fresh or powder)
#     *   Candlenuts (or cashews/macadamia)
#     *   Belacan (fermented shrimp paste - optional but highly recommended)
#     *   Dried shrimp (rehydrated - optional)
# *   **For the Broth:**
#     *   Coconut milk (full-fat)
#     *   Chicken or fish stock (or water)
#     *   Fish sauce
#     *   Sugar
#     *   Oil (for frying paste)
# *   **Main Ingredients:**
#     *   Rice vermicelli noodles
#     *   Thick egg noodles (Hokkien noodles)
#     *   Chicken breast or thighs (cooked and shredded)
#     *   Shrimp (peeled and deveined)
#     *   Fish cakes (sliced)
#     *   Tofu puffs (Tau Pok)
# *   **Garnish:**
#     *   Fresh bean sprouts
#     *   Laksa leaves (Vietnamese coriander), roughly chopped
#     *   Lime wedges
#     *   Hard-boiled eggs (halved - optional)
#     *   Chili sambal (for extra heat - optional)

# %% [markdown]
# Enjoy your delicious Asian soup adventures!

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients. Structure it in json format
    """
)
print(response.text)
# Out:
# ```json
# {
#   "asian_soups": [
#     {
#       "name": "Tom Yum Goong (Thai Hot and Sour Shrimp Soup)",
#       "description": "A vibrant and aromatic Thai classic that promises an explosion of flavors! This clear, zesty broth balances spicy chilies, tangy lime, savory fish sauce, and the fragrant notes of lemongrass, galangal, and kaffir lime leaves. Plump, succulent shrimp swim in this exhilarating soup, awakening every single taste bud with its harmonious blend of hot, sour, and savory.",
#       "ingredients": [
#         "Shrimp (peeled, deveined)",
#         "Lemongrass (bruised, sliced)",
#         "Galangal (sliced)",
#         "Kaffir lime leaves (torn)",
#         "Mushrooms (e.g., straw mushrooms, oyster mushrooms)",
#         "Fresh bird's eye chilies (sliced or bruised)",
#         "Lime juice",
#         "Fish sauce",
#         "Thai chili paste (Nam Prik Pao)",
#         "Chicken or vegetable broth",
#         "Cilantro (for garnish)",
#         "Cherry tomatoes (optional)"
#       ]
#     },
#     {
#       "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#       "description": "An incredibly comforting and deeply aromatic Vietnamese staple, Pho Bo is pure soul in a bowl. Its rich, slow-simmered beef broth is infused with a complex symphony of star anise, cinnamon, ginger, and cloves. Thinly sliced beef (raw, cooked, or both) and slippery rice noodles are bathed in this fragrant elixir, served with a generous side of fresh herbs, bean sprouts, and lime for a truly customizable and deeply satisfying experience.",
#       "ingredients": [
#         "Beef bones (marrow bones, oxtail)",
#         "Beef chuck or flank steak (for broth)",
#         "Thinly sliced raw beef (e.g., sirloin, eye of round)",
#         "Flat rice noodles (Banh Pho)",
#         "Onions (charred)",
#         "Ginger (charred)",
#         "Star anise",
#         "Cinnamon sticks",
#         "Cloves",
#         "Black cardamom pods",
#         "Fish sauce",
#         "Sugar",
#         "Bean sprouts (for serving)",
#         "Fresh basil (Thai basil, for serving)",
#         "Mint (for serving)",
#         "Cilantro (for serving)",
#         "Lime wedges (for serving)",
#         "Jalapeño or serrano peppers (sliced, for serving)"
#       ]
#     },
#     {
#       "name": "Shoyu Ramen (Japanese Soy Sauce Ramen)",
#       "description": "A classic Japanese comfort food that warms you from the inside out! This Shoyu Ramen features a deeply savory chicken or pork broth, masterfully seasoned with a distinctive soy sauce (shoyu) tare. Springy wheat noodles, melt-in-your-mouth chashu pork, a perfectly jammy ajitama (marinated soft-boiled egg), crisp nori, and vibrant scallions come together in a bowl of pure umami bliss that's both hearty and refined.",
#       "ingredients": [
#         "Ramen noodles (fresh or dried)",
#         "Chicken or pork broth (or dashi)",
#         "Soy sauce (shoyu)",
#         "Mirin",
#         "Sake (optional)",
#         "Garlic",
#         "Ginger",
#         "Spring onions (scallions, sliced)",
#         "Chashu pork (braised pork belly or shoulder)",
#         "Ajitama (marinated soft-boiled egg)",
#         "Nori (seaweed sheets)",
#         "Bamboo shoots (menma)",
#         "Sesame oil (for drizzling)"
#       ]
#     },
#     {
#       "name": "Laksa (Malaysian/Singaporean Spicy Coconut Noodle Soup)",
#       "description": "A truly captivating Southeast Asian delight, Laksa is a rich, creamy, and gloriously spicy coconut curry noodle soup. Its luscious broth is deeply flavored with a complex, aromatic spice paste, showcasing hints of lemongrass, galangal, and dried chilies. A generous mix of vermicelli and thick wheat noodles are drenched in this golden elixir, typically laden with succulent shrimp, fish cake, and chewy tofu puffs, offering an unforgettable explosion of sweet, savory, and spicy notes in every slurp.",
#       "ingredients": [
#         "Coconut milk",
#         "Laksa paste (homemade or store-bought: typically includes shallots, garlic, dried chilies, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste)",
#         "Chicken or fish broth",
#         "Shrimp (peeled)",
#         "Fish cake (sliced)",
#         "Tofu puffs (tau pok)",
#         "Vermicelli noodles",
#         "Thick wheat noodles (Hokkien noodles)",
#         "Bean sprouts",
#         "Laksa leaves (Vietnamese coriander/Daun Kesom, for garnish)",
#         "Lime wedges (for serving)",
#         "Fish sauce",
#         "Sugar"
#       ]
#     }
#   ]
# }
# ```

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]

client=genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config = {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [{"recipe_name":"Tom Yum Goong","description":"A classic Thai hot and sour soup, bursting with aromatic herbs, succulent shrimp, and a spicy, tangy broth that will awaken your taste buds.","ingredients":["Shrimp","Lemongrass","Galangal","Kaffir lime leaves","Fish sauce","Lime juice","Mushrooms","Chili paste","Chilies","Cilantro"]}, {"recipe_name":"Miso Soup","description":"A comforting and savory Japanese soup, featuring a delicate dashi broth infused with umami-rich miso paste, tender tofu, and seaweed.","ingredients":["Miso paste","Dashi stock","Tofu","Wakame seaweed","Green onions"]}, {"recipe_name":"Pho Bo","description":"A fragrant Vietnamese beef noodle soup, renowned for its deeply savory and aromatic broth, tender slices of beef, and a medley of fresh herbs and rice noodles.","ingredients":["Beef bones","Beef brisket","Rice noodles","Fish sauce","Ginger","Onion","Star anise","Cinnamon stick","Cardamom pods","Clove","Cilantro","Basil","Lime","Bean sprouts","Chili"]}]

# %%
recipes = response.parsed
recipes
# Out:
# [Recipe(recipe_name='Tom Yum Goong', description='A classic Thai hot and sour soup, bursting with aromatic herbs, succulent shrimp, and a spicy, tangy broth that will awaken your taste buds.', ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Fish sauce', 'Lime juice', 'Mushrooms', 'Chili paste', 'Chilies', 'Cilantro']),
#  Recipe(recipe_name='Miso Soup', description='A comforting and savory Japanese soup, featuring a delicate dashi broth infused with umami-rich miso paste, tender tofu, and seaweed.', ingredients=['Miso paste', 'Dashi stock', 'Tofu', 'Wakame seaweed', 'Green onions']),
#  Recipe(recipe_name='Pho Bo', description='A fragrant Vietnamese beef noodle soup, renowned for its deeply savory and aromatic broth, tender slices of beef, and a medley of fresh herbs and rice noodles.', ingredients=['Beef bones', 'Beef brisket', 'Rice noodles', 'Fish sauce', 'Ginger', 'Onion', 'Star anise', 'Cinnamon stick', 'Cardamom pods', 'Clove', 'Cilantro', 'Basil', 'Lime', 'Bean sprouts', 'Chili'])]

# %%
type(recipes), len(recipes)
# Out:
# (list, 3)

# %%
recipes[0]
# Out:
# Recipe(recipe_name='Tom Yum Goong', description='A classic Thai hot and sour soup, bursting with aromatic herbs, succulent shrimp, and a spicy, tangy broth that will awaken your taste buds.', ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Fish sauce', 'Lime juice', 'Mushrooms', 'Chili paste', 'Chilies', 'Cilantro'])

# %%
recipes[-1].recipe_name, recipes[-1].ingredients
# Out:
# ('Pho Bo',
#  ['Beef bones',
#   'Beef brisket',
#   'Rice noodles',
#   'Fish sauce',
#   'Ginger',
#   'Onion',
#   'Star anise',
#   'Cinnamon stick',
#   'Cardamom pods',
#   'Clove',
#   'Cilantro',
#   'Basil',
#   'Lime',
#   'Bean sprouts',
#   'Chili'])

# %% [markdown]
# ## Simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_rooms: int
    type: Literal["apartment", "house"]
    address: str



response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents = """List 50 apartments and houses in Sweden with their monthly_fee, their price, living area,
    number of rooms, address, type if it is apartment or house.
    All currencies are in SEK.""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)


homes = response.parsed
homes[:3]
# Out:
# [Home(price=4500000, monthly_fee=3800, living_area=75.5, number_rooms=3, type='apartment', address='Sveavägen 42, 111 34 Stockholm'),
#  Home(price=6200000, monthly_fee=2500, living_area=150.0, number_rooms=5, type='house', address='Ribersborgsvägen 10, 217 53 Malmö'),
#  Home(price=3800000, monthly_fee=4100, living_area=68.0, number_rooms=2, type='apartment', address='Kungsportsavenyen 15, 411 36 Göteborg')]

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#      price  monthly_fee  living_area  number_rooms       type  \
# 0  4500000         3800         75.5             3  apartment
# 1  6200000         2500        150.0             5      house
# 2  3800000         4100         68.0             2  apartment
# 3  5500000         2200        135.5             6      house
# 4  2100000         3200         55.0             2  apartment
#
#                                  address
# 0         Sveavägen 42, 111 34 Stockholm
# 1      Ribersborgsvägen 10, 217 53 Malmö
# 2  Kungsportsavenyen 15, 411 36 Göteborg
# 3    Luthagsesplanaden 3, 752 25 Uppsala
# 4              Storgatan 30, 903 26 Umeå

# %%
df.query("price < 2_000_000")
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 9   1850000         2900         45.5             1  apartment
# 27  1950000         3100         50.0             2  apartment
# 31  1500000         2850         42.0             1  apartment
# 44  1790000         3050         48.0             2  apartment
#
#                              address
# 9   Drottninggatan 12, 702 10 Örebro
# 27      Nygatan 18, 582 19 Linköping
# 31        Gruvvägen 8, 981 31 Kiruna
# 44     Järnvägsgatan 9, 803 20 Gävle
