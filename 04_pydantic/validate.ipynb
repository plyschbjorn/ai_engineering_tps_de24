# %% [markdown]
# # Validate with pydantic

# %%
from pydantic import BaseModel, ValidationError

class Student(BaseModel):
    name: str
    age: int
    gender: str

s1 =Student(name="Eva",gender="F",age=8)
s1
# Out:
# Student(name='Eva', age=8, gender='F')

# %%
try:
    Student(name=2.714, gender="F", age=8)
except ValidationError as err:
    print(err)
# Out:
# 1 validation error for Student
# name
#   Input should be a valid string [type=string_type, input_value=2.714, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
